# %% [markdown]
# <a href="https://colab.research.google.com/github/paulaperales/files_renamer/blob/main/PRUEBA_1_YOLO3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %cd /content/gdrive/My Drive/TFG/PRIMERA_BASE_DATOS/yolo/val

# !ls
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# barbados_scuba_002_B_1739.txt  barbados_scuba_011_C_3505.txt
# barbados_scuba_002_B_1740.txt  barbados_scuba_011_C_3506.txt
# barbados_scuba_002_B_1741.txt  barbados_scuba_011_C_3507.txt
# barbados_scuba_002_B_1742.txt  barbados_scuba_011_C_3508.txt
# barbados_scuba_002_B_1743.txt  barbados_scuba_011_C_3509.txt
# barbados_scuba_002_B_1744.txt  barbados_scuba_011_C_3510.txt
# barbados_scuba_002_B_1745.txt  barbados_scuba_011_C_3511.txt
# barbados_scuba_002_B_1746.txt  barbados_scuba_011_C_3512.txt
# barbados_scuba_002_B_1747.txt  barbados_scuba_011_C_3513.txt
# barbados_scuba_002_B_1748.txt  barbados_scuba_011_C_3514.txt
# barbados_scuba_002_B_1749.txt  barbados_scuba_011_C_3515.txt
# barbados_scuba_002_B_1750.txt  barbados_scuba_011_C_3516.txt
# barbados_scuba_002_B_1751.txt  barbados_scuba_011_C_3517.txt
# barbados_scuba_002_B_1752.txt  barbados_scuba_011_C_3518.txt
# ...

# %%
import glob, os

# Current directory
current_dir = '/content/gdrive/My Drive/TFG/PRIMERA_BASE_DATOS/yolo/val'

# del 1 al 5938
files_list = []
for pathAndFilename in glob.iglob(os.path.join(current_dir, "*")):
      if pathAndFilename.find('pool_swimmer_003_A_') != -1:
        separated = pathAndFilename.split("/")
        file_name = separated[8].split("_")
        num_filename = file_name[4].split(".")[0]
        files_list.append(num_filename)

files_list.sort()
print(files_list)
order = '0044'
for i in files_list:
  # print(i==order, i, order)
  if i != order:
    for pathAndFilename in glob.iglob(os.path.join(current_dir, "*")):
      if pathAndFilename.find('pool_swimmer_003_A_' + str(i)) != -1: 
        separated = pathAndFilename.split("/")
        #os.rename(pathAndFilename, (current_dir + '/pool_scuba_001_A_' + order + '.txt'))
        print(pathAndFilename, i, order, (current_dir + '/pool_swimmer_003_A_' + order + '.txt'))
  order_int = int(order) + 1
  order = str(order_int)
  if len(order) < 4:
    if len(order) == 3:
      order = '0' + order
    elif len(order) == 2:
      order = '00' + order
    elif len(order) == 1:
      order = '000' + order
# Out:
# ['0044', '0045', '0046', '0047', '0048', '0049', '0050', '0051', '0052', '0053', '0054', '0055', '0056', '0057', '0058', '0059', '0060', '0061', '0062', '0063', '0064', '0065', '0066', '0067', '0068', '0069', '0070', '0071', '0072', '0073', '0074', '0075', '0076', '0077', '0078', '0079', '0080', '0081', '0082', '0083', '0084', '0085', '0086', '0087', '0088', '0089', '0090', '0091', '0092', '0093', '0094', '0095', '0096', '0097', '0098', '0099', '0100', '0101', '0102', '0103', '0104', '0105', '0106', '0107', '0108', '0109', '0110', '0111', '0112', '0113', '0114', '0115', '0116', '0117', '0118', '0119', '0120', '0121', '0122', '0123', '0124', '0125', '0126', '0127', '0128', '0129', '0130', '0131', '0132', '0133', '0134', '0135', '0136', '0137', '0138', '0139', '0140', '0141', '0142', '0143', '0144', '0145', '0146', '0147', '0148', '0149', '0150', '0151', '0152', '0153', '0154', '0155', '0156', '0157', '0158', '0159', '0160', '0161', '0162', '0163', '0164', '0165', '0166', '0167', '0168
# ...
